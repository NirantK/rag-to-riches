# %%
import instructor
from openai import OpenAI
from typing import Iterable, Literal, List, Optional, Tuple
from pydantic import BaseModel, Field 
import pandas as pd

# %%
client = instructor.from_openai(OpenAI(), mode=instructor.Mode.TOOLS)

class Facet(BaseModel):
    """
    Facet is a search filter e.g. color, size, price, etc.
    """
    name: str = Field(..., description="Common filters in search e.g. color, size, price, gender, brand, fit, cut,datetime, season, pattern, material, dimension, etc.")
    values: List[str] = Field(..., description="Values of the facet")

class QueryAnnotation(BaseModel):
    query: str = Field(..., description="Query to search for relevant content")
    simplified_query: str = Field(..., description="Simplified query e.g. wristwatches for men -> men's wristwatches, red dress shirt for husband -> men's red dress shirt")
    hypothetical_product_description: Optional[List[str]] = Field(..., description="Given a query, generate unique and diverse product descriptions that satisfy the query")
    keywords: List[str] = Field(..., description=   "Keywords to search for")
    expanded_keywords: List[str] = Field(..., description="Expanded keywords to search for e.g. synonyms, related words, etc.")
    intent: Literal["informational", "navigational", "transactional"] = Field(..., description="Intent of the user")
    translated_query: Optional[str] = Field(..., description="English query to search for")
    iso_language_code: Optional[str] = Field(..., description="ISO language code to search e.g. en-US, in-IN")
    facets: List[Facet] = Field(..., description="Facets which are used to filter the search results")

    async def execute(self):
        print(
            f"Decomposing query `{self.query}` into `{self.simplified_query}` and `{self.semantic_query}`"
        )

# %%
df = pd.read_json("amzn_esci_train_query_info.jsonl", lines=True)
df.head()
# Out:
#    qid                                             q_text
# 0    1                       !awnmower tires without rims
# 1    5            # 10 self-seal envelopes without window
# 2    6                          # 2 pencils not sharpened
# 3    9                                         # mom life
# 4   11  #1 best and not expensive bath back brush crea...

# %% [markdown]
# query = f(queries, products, user_actions)

# %%
def query_annotation(data: str) -> Iterable[QueryAnnotation]:
    return client.chat.completions.create(
        model="gpt-4o",
        response_model=Iterable[QueryAnnotation],
        messages=[
            {
                "role": "user",
                "content": f"Consider the user query below: '\n{data}' and annotate the query",
            },
        ],
        max_tokens=1000,
        temperature=0.0,
        seed=42,
    )

def image_query_annotation(url: str, query: str) -> Iterable[QueryAnnotation]:
    return client.chat.completions.create(
        model="gpt-4o",
        response_model=Iterable[QueryAnnotation],
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "image_url",
                        "image_url": {"url": url},
                    },
                    {
                        "type": "text",
                        "text": f"Analyze the image and annotate the query: {query}",
                    },
                ],
            }
        ],
        max_tokens=1000,
        temperature=0.0,
        seed=42,
    )

for query in query_annotation("I'm looking for a red dress shirt for my husband for a Bertem wedding"):
    print(query.model_dump_json(indent=2))
# Out:
# {
#   "query": "red dress shirt for my husband for a Bertem wedding",
#   "simplified_query": "men's red dress shirt",
#   "hypothetical_product_description": [
#     "A stylish men's red dress shirt made from high-quality cotton, perfect for formal occasions such as weddings. It features a slim fit design, button-down collar, and long sleeves.",
#     "A vibrant red dress shirt for men, crafted from breathable fabric, ideal for weddings and other formal events. It comes with a classic fit, spread collar, and adjustable cuffs."
#   ],
#   "keywords": [
#     "red dress shirt",
#     "men's dress shirt",
#     "wedding shirt"
#   ],
#   "expanded_keywords": [
#     "men's red dress shirt",
#     "formal red shirt",
#     "wedding dress shirt",
#     "husband's red dress shirt"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "color",
#       "values": [
#         "red"
#       ]
#     },
#     {
#       "name": "gender",
#       "values": [
#         "men"
#       ]
#     },
#     {
#       "name": "occasion",
#       "values": [
#         "wedding"
#       ]
#     }
#   ]
# }

# %%
from IPython.display import Image
from IPython.core.display import HTML

def display_image_from_url(url: str):
    return Image(url=url)

# Display the image
display(HTML("<h3>Sample Image</h3>"))
display(display_image_from_url("https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Blue_sari_2.jpg/920px-Blue_sari_2.jpg"))


for query in image_query_annotation("https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Blue_sari_2.jpg/920px-Blue_sari_2.jpg", "I'm looking for a kanchipuram silk saree"):
    print(query.model_dump_json(indent=2))
# Out:
# <h3>Sample Image</h3>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Blue_sari_2.jpg/920px-Blue_sari_2.jpg"/>
# {
#   "query": "I'm looking for a kachipuram silk saree",
#   "simplified_query": "kachipuram silk saree",
#   "hypothetical_product_description": [
#     "This exquisite Kachipuram silk saree features intricate zari work and a rich, vibrant color palette, perfect for weddings and special occasions.",
#     "A traditional Kachipuram silk saree with a beautiful temple border and pallu, showcasing the craftsmanship of South Indian weavers.",
#     "Elegant Kachipuram silk saree in a deep maroon shade, adorned with gold motifs and a contrasting border, ideal for festive celebrations."
#   ],
#   "keywords": [
#     "kachipuram silk saree",
#     "kachipuram saree",
#     "silk saree",
#     "traditional saree"
#   ],
#   "expanded_keywords": [
#     "kachipuram silk saree",
#     "kachipuram saree",
#     "silk saree",
#     "traditional saree",
#     "south indian saree",
#     "zari work saree",
#     "wedding saree",
#     "festive saree"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "color",
#       "values": [
#         "maroon",
#         "red",
#         "green",
#         "blue",
#         "purple"
#       ]
#     },
#     {
#       "name": "occasion",
#       "values": [
#         "wedding",
#         "festive",
#         "special occasion"
#       ]
#     },
#     {
#       "name": "material",
#       "values": [
#         "silk"
#       ]
#     },
#     {
#       "name": "work",
#       "values": [
#         "zari",
#         "motifs",
#         "temple border"
#       ]
#     }
#   ]
# }

# %%
# Pull 100 random queries from the df and display
def display_annotated_queries(queries: List[str]):
    for query in queries:
        annotated_queries = query_annotation(query)
        for annotated_query in annotated_queries:
            print(f"Query: {query}")
            print(f"Annotated Query: {annotated_query.model_dump_json(indent=2)}")
            print("\n")

seed = 69
queries = df["q_text"].sample(10, random_state=seed).tolist()
display_annotated_queries(queries)
# Out:
# Query: waterproof kid gloves small
# Annotated Query: {
#   "id": "1",
#   "query": "waterproof kid gloves small",
#   "simplified_query": "small waterproof kid gloves",
#   "hypothetical_product_description": [
#     "These small waterproof kid gloves are perfect for keeping little hands dry and warm during rainy or snowy weather. Made with durable, water-resistant materials, they offer excellent protection against the elements while ensuring comfort and flexibility for active kids. Available in various colors and designs to suit every child's preference."
#   ],
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "waterproof",
#     "kid gloves",
#     "small"
#   ],
#   "expanded_keywords": [
#     "water-resistant",
#     "children's gloves",
#     "small size",
#     "youth gloves",
#     "rain gloves",
#     "snow gloves"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "size",
#       "values": [
#         "small"
#       ]
#     },
#     {
#       "name": "feature",
#       "values": [
#         "waterproof"
#       ]
#     },
#     {
#       "name": "target audience",
#       "values": [
#         "kids"
#       ]
#     }
#   ]
# }
#
#
# Query: black marble blanket
# Annotated Query: {
#   "id": "1",
#   "query": "black marble blanket",
#   "simplified_query": "black marble blanket",
#   "hypothetical_product_description": [
#     "A luxurious black marble blanket made from high-quality, soft, and durable materials. The blanket features a unique marble pattern in shades of black and gray, providing a sophisticated and modern look. Perfect for adding a touch of elegance to any bedroom or living space.",
#     "A cozy and warm black marble blanket designed with a striking marble pattern. Made from premium fleece, this blanket is ideal for snuggling up on the couch or as an extra layer on your bed. The black and white marble design adds a contemporary flair to your home decor."
#   ],
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "black marble blanket",
#     "marble pattern blanket",
#     "black and gray blanket"
#   ],
#   "expanded_keywords": [
#     "black marble blanket",
#     "marble pattern blanket",
#     "black and gray blanket",
#     "luxury blanket",
#     "modern blanket",
#     "elegant blanket"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "color",
#       "values": [
#         "black",
#         "gray"
#       ]
#     },
#     {
#       "name": "pattern",
#       "values": [
#         "marble"
#       ]
#     },
#     {
#       "name": "material",
#       "values": [
#         "fleece",
#         "soft",
#         "durable"
#       ]
#     }
#   ]
# }
#
#
# Query: purple race car toy
# Annotated Query: {
#   "id": "1",
#   "query": "purple race car toy",
#   "simplified_query": "purple race car toy",
#   "hypothetical_product_description": [
#     "A sleek and stylish purple race car toy with realistic detailing and high-speed capabilities, perfect for young racing enthusiasts.",
#     "A durable and vibrant purple race car toy made from high-quality materials, featuring a pull-back mechanism for fast racing action.",
#     "A battery-operated purple race car toy with flashing lights and sound effects, designed to provide hours of entertainment for kids."
#   ],
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "purple",
#     "race car",
#     "toy"
#   ],
#   "expanded_keywords": [
#     "violet",
#     "racing car",
#     "children's toy"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "color",
#       "values": [
#         "purple"
#       ]
#     },
#     {
#       "name": "type",
#       "values": [
#         "race car",
#         "toy"
#       ]
#     },
#     {
#       "name": "age group",
#       "values": [
#         "children"
#       ]
#     }
#   ]
# }
#
#
# Query: necklace with name
# Annotated Query: {
#   "id": "1",
#   "query": "necklace with name",
#   "simplified_query": "personalized name necklace",
#   "hypothetical_product_description": [
#     "A delicate gold necklace featuring a customizable nameplate, perfect for adding a personal touch to any outfit.",
#     "A sterling silver necklace with a name pendant, ideal for gifting to loved ones.",
#     "A trendy rose gold necklace with a personalized name charm, suitable for everyday wear."
#   ],
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "necklace",
#     "name",
#     "personalized",
#     "customizable",
#     "nameplate"
#   ],
#   "expanded_keywords": [
#     "custom name necklace",
#     "name pendant",
#     "personalized jewelry",
#     "customizable necklace",
#     "name charm"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "material",
#       "values": [
#         "gold",
#         "silver",
#         "rose gold"
#       ]
#     },
#     {
#       "name": "occasion",
#       "values": [
#         "gift",
#         "everyday wear"
#       ]
#     },
#     {
#       "name": "style",
#       "values": [
#         "delicate",
#         "trendy"
#       ]
#     }
#   ]
# }
#
#
# Query: dogs
# Annotated Query: {
#   "id": "1",
#   "query": "dogs",
#   "simplified_query": "dogs",
#   "hypothetical_product_description": null,
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "dogs"
#   ],
#   "expanded_keywords": [
#     "canines",
#     "puppies",
#     "dog breeds",
#     "pet dogs",
#     "dog care"
#   ],
#   "intent": "informational",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": []
# }
#
#
# Query: adhesive document pockets 9.5 x 12
# Annotated Query: {
#   "id": "1",
#   "query": "adhesive document pockets 9.5 x 12",
#   "simplified_query": "adhesive document pockets 9.5 x 12",
#   "hypothetical_product_description": [
#     "These adhesive document pockets are perfect for organizing and protecting your important papers. Measuring 9.5 x 12 inches, they are designed to fit standard letter-sized documents. The strong adhesive backing ensures that the pockets stay securely in place on any surface, whether it's a binder, folder, or wall. Made from durable, transparent material, these pockets allow you to easily view the contents without removing them. Ideal for office, school, or home use."
#   ],
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "adhesive document pockets",
#     "9.5 x 12 document pockets",
#     "adhesive pockets for documents"
#   ],
#   "expanded_keywords": [
#     "self-adhesive document pockets",
#     "sticky document holders",
#     "adhesive file pockets",
#     "9.5 x 12 adhesive pockets"
#   ],
#   "intent": "informational",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "size",
#       "values": [
#         "9.5 x 12"
#       ]
#     },
#     {
#       "name": "type",
#       "values": [
#         "adhesive"
#       ]
#     },
#     {
#       "name": "material",
#       "values": [
#         "transparent"
#       ]
#     }
#   ]
# }
#
#
# Query: soccer clothes for girls
# Annotated Query: {
#   "id": "1",
#   "query": "soccer clothes for girls",
#   "simplified_query": "girls' soccer clothes",
#   "hypothetical_product_description": [
#     "A stylish and comfortable soccer jersey designed specifically for girls, featuring moisture-wicking fabric and vibrant colors.",
#     "Durable and flexible soccer shorts for girls, providing ease of movement and breathability during intense matches.",
#     "High-quality soccer socks for girls, offering extra cushioning and support for long hours of play.",
#     "A complete soccer uniform set for girls, including a jersey, shorts, and socks, all made from premium materials."
#   ],
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "soccer clothes",
#     "girls' soccer clothes",
#     "soccer jersey",
#     "soccer shorts",
#     "soccer socks"
#   ],
#   "expanded_keywords": [
#     "girls' soccer apparel",
#     "youth soccer clothes",
#     "girls' sportswear",
#     "soccer gear for girls"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "gender",
#       "values": [
#         "girls"
#       ]
#     },
#     {
#       "name": "sport",
#       "values": [
#         "soccer"
#       ]
#     },
#     {
#       "name": "age group",
#       "values": [
#         "youth",
#         "children"
#       ]
#     }
#   ]
# }
#
#
# Query: how to not give a fck book
# Annotated Query: {
#   "id": "1",
#   "query": "how to not give a fck book",
#   "simplified_query": "how to not give a f*ck book",
#   "hypothetical_product_description": [
#     "A self-help book that teaches readers how to stop worrying about what others think and focus on their own happiness.",
#     "A guide to living a more carefree and authentic life by not caring about societal pressures."
#   ],
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "how to not give a f*ck",
#     "self-help book",
#     "carefree living"
#   ],
#   "expanded_keywords": [
#     "how to not give a f*ck",
#     "self-help book",
#     "carefree living",
#     "authentic life",
#     "stop worrying",
#     "happiness"
#   ],
#   "intent": "informational",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": []
# }
#
#
# Query: call of duty modern warfare xbox one
# Annotated Query: {
#   "id": "1",
#   "query": "call of duty modern warfare xbox one",
#   "simplified_query": "call of duty modern warfare xbox one",
#   "hypothetical_product_description": [
#     "Call of Duty: Modern Warfare for Xbox One is an intense first-person shooter game that offers a gripping single-player campaign and thrilling multiplayer modes. Experience realistic graphics, immersive sound, and a variety of weapons and missions. Perfect for fans of action-packed war games."
#   ],
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "call of duty",
#     "modern warfare",
#     "xbox one",
#     "call of duty modern warfare",
#     "call of duty xbox one"
#   ],
#   "expanded_keywords": [
#     "call of duty",
#     "modern warfare",
#     "xbox one",
#     "call of duty modern warfare",
#     "call of duty xbox one",
#     "cod modern warfare",
#     "cod xbox one",
#     "modern warfare game",
#     "call of duty game"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "platform",
#       "values": [
#         "Xbox One"
#       ]
#     },
#     {
#       "name": "game series",
#       "values": [
#         "Call of Duty"
#       ]
#     },
#     {
#       "name": "genre",
#       "values": [
#         "First-person shooter"
#       ]
#     }
#   ]
# }
#
#
# Query: fingerpow
# Annotated Query: {
#   "id": "1",
#   "query": "'fingerpow'",
#   "simplified_query": "fingerpow",
#   "hypothetical_product_description": [
#     "Fingerpow is a portable, magnetic, and modular charging solution designed for smartphones and other small electronic devices. It consists of small, detachable battery packs that can be easily attached to your device for on-the-go charging. Each pack provides a quick boost of power, making it ideal for emergencies or daily use when you need a quick charge without carrying bulky power banks."
#   ],
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "fingerpow",
#     "portable charger",
#     "magnetic charger",
#     "modular charger"
#   ],
#   "expanded_keywords": [
#     "portable power bank",
#     "emergency charger",
#     "detachable battery pack",
#     "smartphone charger"
#   ],
#   "intent": "informational",
#   "translated_query": "fingerpow",
#   "iso_language_code": "en-US",
#   "facets": []
# }
