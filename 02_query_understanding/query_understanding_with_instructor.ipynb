# %%
import instructor
from openai import OpenAI
from typing import Iterable, Literal, List, Optional, Tuple
from pydantic import BaseModel, Field 
import pandas as pd

# %%
# Apply the patch to the OpenAI client
# enables response_model keyword
client = instructor.from_openai(OpenAI())

class Facet(BaseModel):
    """
    Facet is a search filter e.g. color, size, price, etc.
    """
    name: str = Field(..., description="Common filters in search e.g. color, size, price, gender, datetime, season, pattern, material, dimension, etc.")
    values: List[str] = Field(..., description="Values of the facet")

class QueryAnnotation(BaseModel):
    id: str = Field(..., description="Unique Query ID") 
    query: str = Field(..., description="Query to search for relevant content")
    simplified_query: str = Field(..., description="Simplified query e.g. wristwatches for men -> men's wristwatches, red dress shirt for husband -> men's red dress shirt")
    hypothetical_document_query: Optional[str] = Field(..., description="Given a question, generate possible product descriptions that satisfy the query")
    type: Literal["web", "image", "video"] = Field(..., description="Document type to search for")
    rag_query_type: Literal["lookup", "synthesis", "inference", "temporal", "comparative", "hypothetical", "multihop_query", "unanswerable", "recommendation"] = Field(..., description="RAG query type")
    keywords: List[str] = Field(..., description=   "Keywords to search for")
    expanded_keywords: List[str] = Field(..., description="Expanded keywords to search for")
    intent: Literal["informational", "navigational", "transactional"] = Field(..., description="Intent of the user")
    translated_query: Optional[str] = Field(..., description="English query to search for")
    iso_language_code: Optional[str] = Field(..., description="ISO language code to search e.g. en-US, in-IN")
    facets: List[Facet] = Field(..., description="Facets which are used to filter the search results")

    async def execute(self):
        print(
            f"Decomposing query `{self.query}` into `{self.simplified_query}` and `{self.semantic_query}`"
        )

# %%
df = pd.read_csv("queries_dev.tsv", sep="\t", names=["qid", "query", "region"])
df.head()
# Out:
#    qid                                              query  \
# 0    1                      +www.govictory.com/flashpoint
# 1    2                              022 orange pill round
# 2    3  1 – (adaptado enem 2011).um dos processos usad...
# 3    4                    14 day weather forecast chicago
# 4    5                   15034 appleton port charlotte fl
#
#                                         region
# 0                                        en-US
# 1                  en-US,  fr-FR, en-AU, en-US
# 2                                        pt-BR
# 3   en-IE,  en-US,  fr-FR, en-CA, en-GB, en-US
# 4                                        en-US

# %%
def query_annotation(data: str) -> Iterable[QueryAnnotation]:
    return client.chat.completions.create(
        model="gpt-4o-mini",
        response_model=Iterable[QueryAnnotation],
        messages=[
            {
                "role": "user",
                "content": f"Consider the user query below: '\n{data}' and annotate the query",
            },
        ],
        max_tokens=1000,
        temperature=0.0,
        seed=42,
    )

for query in query_annotation("I'm a little confused. I'm looking for a red dress shirt for my husband. I'm not sure if I should be looking for a solid color or one with some pattern. What do you think?"):
    print(query.model_dump_json(indent=2))
# Out:
# {
#   "id": "1",
#   "query": "red dress shirt for husband",
#   "simplified_query": "men's red dress shirt",
#   "hypothetical_document_query": "A stylish men's red dress shirt, available in both solid and patterned options, perfect for formal or casual occasions.",
#   "type": "web",
#   "rag_query_type": "recommendation",
#   "keywords": [
#     "red",
#     "dress shirt",
#     "husband",
#     "men's clothing"
#   ],
#   "expanded_keywords": [
#     "red dress shirt",
#     "men's red dress shirt",
#     "red shirt for husband",
#     "dress shirt for men",
#     "patterned dress shirt"
#   ],
#   "intent": "transactional",
#   "translated_query": "red dress shirt for husband",
#   "iso_language_code": "en-US",
#   "facets": [
#     {
#       "name": "color",
#       "values": [
#         "red"
#       ]
#     },
#     {
#       "name": "gender",
#       "values": [
#         "men"
#       ]
#     },
#     {
#       "name": "type",
#       "values": [
#         "dress shirt"
#       ]
#     },
#     {
#       "name": "pattern",
#       "values": [
#         "solid",
#         "patterned"
#       ]
#     }
#   ]
# }

# %%
# Pull 100 random queries from the df and display
def display_annotated_queries(queries: List[str]):
    for query in queries:
        annotated_queries = query_annotation(query)
        for annotated_query in annotated_queries:
            print(annotated_query.model_dump_json(indent=2))

seed = 37
queries = df["query"].sample(10, random_state=seed).tolist()
display_annotated_queries(queries)
# Out:
# {
#   "id": "1",
#   "query": "disfrutar vacaciones tras it",
#   "simplified_query": "disfrutar vacaciones",
#   "hypothetical_document_query": "¿Cómo disfrutar de unas vacaciones tras un viaje a Italia?",
#   "type": "web",
#   "rag_query_type": "synthesis",
#   "keywords": [
#     "disfrutar",
#     "vacaciones",
#     "tras",
#     "it"
#   ],
#   "expanded_keywords": [
#     "disfrutar vacaciones",
#     "vacaciones tras it",
#     "vacaciones en Italia"
#   ],
#   "intent": "informational",
#   "translated_query": "enjoy vacations after it",
#   "iso_language_code": "es-ES",
#   "facets": [
#     {
#       "name": "destination",
#       "values": [
#         "Italia"
#       ]
#     },
#     {
#       "name": "activity",
#       "values": [
#         "vacaciones",
#         "disfrutar"
#       ]
#     }
#   ]
# }
# {
#   "id": "1",
#   "query": "is vanity fair biased",
#   "simplified_query": "is Vanity Fair biased",
#   "hypothetical_document_query": "An analysis of Vanity Fair's editorial stance and potential biases in its reporting.",
#   "type": "web",
#   "rag_query_type": "inference",
#   "keywords": [
#     "Vanity Fair",
#     "biased",
#     "media bias",
#     "editorial stance"
#   ],
#   "expanded_keywords": [
#     "Vanity Fair magazine",
#     "media bias analysis",
#     "editorial bias",
#     "journalistic integrity"
#   ],
#   "intent": "informational",
#   "translated_query": null,
#   "iso_language_code": "en-US",
#   "facets": [
#     {
#       "name": "publication",
#       "values": [
#         "Vanity Fair"
#       ]
#     },
#     {
#       "name": "topic",
#       "values": [
#         "media bias",
#         "editorial stance"
#       ]
#     }
#   ]
# }
# {
#   "id": "1",
#   "query": "東京都選挙管理委員会 収支報告書",
#   "simplified_query": "東京都選挙管理委員会の収支報告書",
#   "hypothetical_document_query": "東京都選挙管理委員会の収支報告書に関する情報",
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "東京都",
#     "選挙管理委員会",
#     "収支報告書"
#   ],
#   "expanded_keywords": [
#     "東京都",
#     "選挙管理委員会",
#     "収支",
#     "報告書"
#   ],
#   "intent": "informational",
#   "translated_query": "Tokyo Election Management Committee financial report",
#   "iso_language_code": "ja-JP",
#   "facets": [
#     {
#       "name": "type",
#       "values": [
#         "financial report",
#         "government document"
#       ]
#     },
#     {
#       "name": "region",
#       "values": [
#         "Tokyo"
#       ]
#     }
#   ]
# }
# {
#   "id": "1",
#   "query": "結婚祝い 予算",
#   "simplified_query": "結婚祝いの予算",
#   "hypothetical_document_query": "What is a reasonable budget for wedding gifts?",
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "結婚祝い",
#     "予算",
#     "ギフト",
#     "贈り物"
#   ],
#   "expanded_keywords": [
#     "結婚祝いの予算",
#     "結婚祝いの相場",
#     "結婚祝いのギフト",
#     "結婚祝いの贈り物"
#   ],
#   "intent": "informational",
#   "translated_query": "wedding gift budget",
#   "iso_language_code": "ja-JP",
#   "facets": [
#     {
#       "name": "price",
#       "values": [
#         "5000円以下",
#         "5000円〜10000円",
#         "10000円〜30000円",
#         "30000円以上"
#       ]
#     },
#     {
#       "name": "type",
#       "values": [
#         "現金",
#         "ギフト券",
#         "物品"
#       ]
#     }
#   ]
# }
# {
#   "id": "1",
#   "query": "お礼のあいさつ",
#   "simplified_query": "お礼",
#   "hypothetical_document_query": "お礼のあいさつの例文や使い方について",
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "お礼",
#     "あいさつ",
#     "挨拶",
#     "感謝"
#   ],
#   "expanded_keywords": [
#     "お礼の言葉",
#     "感謝の挨拶",
#     "お礼のメッセージ"
#   ],
#   "intent": "informational",
#   "translated_query": "greeting of thanks",
#   "iso_language_code": "ja-JP",
#   "facets": [
#     {
#       "name": "type",
#       "values": [
#         "formal",
#         "informal"
#       ]
#     },
#     {
#       "name": "occasion",
#       "values": [
#         "business",
#         "personal"
#       ]
#     }
#   ]
# }
# {
#   "id": "1",
#   "query": "ettori hubert avis",
#   "simplified_query": "ettori hubert reviews",
#   "hypothetical_document_query": "What are the reviews for Ettori Hubert?",
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "ettori",
#     "hubert",
#     "avis",
#     "reviews"
#   ],
#   "expanded_keywords": [
#     "ettori hubert",
#     "ettori hubert avis",
#     "hubert avis",
#     "avis reviews"
#   ],
#   "intent": "informational",
#   "translated_query": "ettori hubert reviews",
#   "iso_language_code": "fr-FR",
#   "facets": [
#     {
#       "name": "type",
#       "values": [
#         "reviews",
#         "ratings"
#       ]
#     },
#     {
#       "name": "language",
#       "values": [
#         "French",
#         "English"
#       ]
#     }
#   ]
# }
# {
#   "id": "1",
#   "query": "что такое кабель",
#   "simplified_query": "что такое кабель",
#   "hypothetical_document_query": "Объясните, что такое кабель и его функции.",
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "кабель",
#     "что такое",
#     "определение"
#   ],
#   "expanded_keywords": [
#     "кабель",
#     "определение кабеля",
#     "функции кабеля"
#   ],
#   "intent": "informational",
#   "translated_query": "what is a cable",
#   "iso_language_code": "ru-RU",
#   "facets": []
# }
# {
#   "id": "1",
#   "query": "五格",
#   "simplified_query": "五格",
#   "hypothetical_document_query": null,
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "五格"
#   ],
#   "expanded_keywords": [
#     "五格"
#   ],
#   "intent": "informational",
#   "translated_query": "Five Elements",
#   "iso_language_code": "zh-CN",
#   "facets": []
# }
# {
#   "id": "1",
#   "query": "maghrib doha today",
#   "simplified_query": "maghrib prayer time in Doha today",
#   "hypothetical_document_query": "What time is the Maghrib prayer in Doha today?",
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "maghrib",
#     "doha",
#     "today",
#     "prayer time"
#   ],
#   "expanded_keywords": [
#     "maghrib prayer",
#     "doha prayer time",
#     "today's maghrib time",
#     "Islamic prayer times in Doha"
#   ],
#   "intent": "informational",
#   "translated_query": "maghrib doha today",
#   "iso_language_code": "en-QA",
#   "facets": [
#     {
#       "name": "datetime",
#       "values": [
#         "today"
#       ]
#     },
#     {
#       "name": "location",
#       "values": [
#         "Doha"
#       ]
#     },
#     {
#       "name": "prayer",
#       "values": [
#         "maghrib"
#       ]
#     }
#   ]
# }
# {
#   "id": "1",
#   "query": "circle border",
#   "simplified_query": "circle border",
#   "hypothetical_document_query": "What are the design options for circle borders?",
#   "type": "web",
#   "rag_query_type": "lookup",
#   "keywords": [
#     "circle",
#     "border"
#   ],
#   "expanded_keywords": [
#     "circular border",
#     "border design",
#     "circle design"
#   ],
#   "intent": "informational",
#   "translated_query": null,
#   "iso_language_code": "en-US",
#   "facets": [
#     {
#       "name": "shape",
#       "values": [
#         "circle"
#       ]
#     },
#     {
#       "name": "style",
#       "values": [
#         "border"
#       ]
#     }
#   ]
# }
